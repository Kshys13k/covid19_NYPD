# %%
import pandas as pd

# %%
df=pd.read_csv("../data/owid-covid-data.csv")
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 401063      ZWE    Africa     Zimbabwe  2024-05-08     266362.0        0.0
# 401064      ZWE    Africa     Zimbabwe  2024-05-09     266362.0        0.0
# 401065      ZWE    Africa     Zimbabwe  2024-05-10     266362.0        0.0
# 401066      ZWE    Africa     Zimbabwe  2024-05-11     266362.0        0.0
# 401067      ZWE    Africa     Zimbabwe  2024-05-12     266362.0        0.0
#
# ...

# %%
dfSpain=df[df["iso_code"]=="ESP"]
dfSpain=dfSpain.reset_index()
dfSpain=dfSpain.drop(columns=["index"])
dfSpain.to_csv("../data/owid-covid-data_spain.csv", index=False)
dfSpain
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 0         ESP    Europe    Spain  2020-01-05          NaN        0.0
# 1         ESP    Europe    Spain  2020-01-06          NaN        0.0
# 2         ESP    Europe    Spain  2020-01-07          NaN        0.0
# 3         ESP    Europe    Spain  2020-01-08          NaN        0.0
# 4         ESP    Europe    Spain  2020-01-09          NaN        0.0
# ...       ...       ...      ...         ...          ...        ...
# 1585      ESP    Europe    Spain  2024-05-08   13980340.0        NaN
# 1586      ESP    Europe    Spain  2024-05-09   13980340.0        NaN
# 1587      ESP    Europe    Spain  2024-05-10   13980340.0        NaN
# 1588      ESP    Europe    Spain  2024-05-11   13980340.0        NaN
# 1589      ESP    Europe    Spain  2024-05-12   13980340.0        NaN
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
dfPoland=df[df["iso_code"]=="POL"]
dfPoland=dfPoland.reset_index()
dfPoland=dfPoland.drop(columns=["index"])
dfPoland.to_csv("../data/owid-covid-data_poland.csv", index=False)
dfPoland
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 0         POL    Europe   Poland  2020-01-05          NaN        0.0
# 1         POL    Europe   Poland  2020-01-06          NaN        0.0
# 2         POL    Europe   Poland  2020-01-07          NaN        0.0
# 3         POL    Europe   Poland  2020-01-08          NaN        0.0
# 4         POL    Europe   Poland  2020-01-09          NaN        0.0
# ...       ...       ...      ...         ...          ...        ...
# 1585      POL    Europe   Poland  2024-05-08    6662631.0        0.0
# 1586      POL    Europe   Poland  2024-05-09    6662631.0        0.0
# 1587      POL    Europe   Poland  2024-05-10    6662631.0        0.0
# 1588      POL    Europe   Poland  2024-05-11    6662631.0        0.0
# 1589      POL    Europe   Poland  2024-05-12    6662732.0      101.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...
